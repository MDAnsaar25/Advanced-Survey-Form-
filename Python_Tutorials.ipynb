# %% [markdown]
# <a href="https://colab.research.google.com/github/MDAnsaar25/Advanced-Survey-Form-/blob/main/Python_Tutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the first class Kailas")
# Out:
# Welcome to the first class Kailas

# %%
print(5+1)
# Out:
# 6

# %%
print("kailas")
# Out:
# kailas

# %% [markdown]
# #Input Statements

# %%
name=input("Enter your name: ")
print(name)
# Out:
# Enter your name: Kailas
# Kailas

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
c = a+b
print(c)
# Out:
# Enter the first number: 590876543
# Enter the second number: 987653
# 591864196

# %% [markdown]
# #Conditional Statements

# %%
num = 4
if num > 4:
  print("This is Python Class")
else:
  print("This is Machine Learning Class")
# Out:
# This is Machine Learning Class

# %%
weather = "raining"
if weather == "raining":
  print("I need to take a cab")
else:
  print("I dont need a cab")
# Out:
# I need to take a cab

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the Second number: "))
choice = input("Enter your Choice: ")
if choice == "Add":
  print("The addition of two numbers is ",number1+number2)
elif choice =="Sub":
  print("The subraction of two numbers is ",number1-number2)
# Out:
# Enter the first number: 5
# Enter the Second number: 7
# Enter your Choice: Sub
# The subraction of two numbers is  -2

# %%
number = int(input())

# %% [markdown]
# #Logical Operators

# %%
a=10
if a>5 and a<15:
  print("The condition is working")
else:
  print("Condition is not working")
# Out:
# The condition is working

# %%
a=10
if a>5 or a<9:
  print("The condition is working")
else:
  print("Condition is not working")
# Out:
# The condition is working

# %%
n=int(input("Enter the number: "))
flag = True
for i in range(2,n):
  if n%i == 0:
    flag = False
    break
if flag:
  print("This is prime number")
else:
  print("This is not a prime number")
# Out:
# Enter the number: 13
# This is prime number

# %%
n=int(input("Enter the number: "))
flag = True
for i in range(2,n):
  if n%i == 0:
    flag = False
    print("This is not a prime number")
    break
  else:
    print("This is a prime number")
# Out:
# Enter the number: 14
# This is not a prime number

# %% [markdown]
# #Sum of Numbers

# %%
n = int(input("Enter the number: "))
add = 0
for i in range(1,n+1):
    add = add+i
print("The sum of given number is",add)
# Out:
# Enter the number: 5
# The sum of given number is 15

# %% [markdown]
# #Product of Numbers

# %%
n = int(input("Enter the number: "))
multiply = 1
for i in range(1,n+1):
    multiply = multiply*i
print("The sum of given number is",multiply)
# Out:
# Enter the number: 5
# The sum of given number is 120

# %% [markdown]
# #
